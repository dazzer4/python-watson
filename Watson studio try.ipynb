# %%
# The code was removed by Watson Studio for sharing.
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
import numpy as plt
import matplotlib.pyplot as plt
import scipy.stats
import statistics


myarr =df_data_1.values
plt.figure
plt.bar(myarr[:,0],myarr[:,2])
plt.show()
plt.scatter(myarr[:,0],myarr[:,6])
plt.show()
a = df_data_1.creatinine_phosphokinase
print (a)
b =statistics.mean(a)

c =scipy.stats.hmean(a)
print (b)
print (c)
# Out:
# 0       582
# 1      7861
# 2       146
# 3       111
# 4       160
# 5        47
# 6       246
# 7       315
# 8       157
# 9       123
# 10       81
# 11      231
# 12      981
# 13      168
# 14       80
# 15      379
# 16      149
# 17      582
# 18      125
# 19      582
# 20       52
# 21      128
# 22      220
# 23       63
# 24      582
# 25      148
# 26      112
# 27      122
# 28       60
# 29       70
#        ...
# 269     582
# 270     582
# 271     582
# 272     213
# 273      64
# 274     257
# 275     582
# 276     618
# 277     582
# 278    1051
# 279      84
# 280    2695
# 281     582
# 282      64
# 283    1688
# 284      54
# 285     170
# 286     253
# 287     582
# 288     892
# 289     337
# 290     615
# 291     320
# 292     190
# 293     103
# 294      61
# 295    1820
# 296    2060
# 297    2413
# 298     196
# Name: creatinine_phosphokinase, Length: 299, dtype: int64
# 581.8394648829432
# 168.8251929466258
